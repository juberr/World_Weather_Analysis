# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

#imports the previous directory for config.py
import sys
sys.path.insert(1, '../')

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("../Vacation_Search/WeatherPy_vacation.csv")
vacation_df = vacation_df.drop(['Unnamed: 0'], axis =1)
vacation_df.head(10)
# Out:
#    City_ID         City Country  Max Temp Current Description    Lat     Lng  \
# 0        0      Nanning      CN     60.80    scattered clouds  22.82  108.32
# 1        1    Carnarvon      AU     71.60           clear sky -24.87  113.63
# 2        2  East London      ZA     66.20           clear sky -33.02   27.91
# 3        3      Rikitea      PF     74.03     overcast clouds -23.12 -134.97
# 4        4     Flinders      AU     66.00     overcast clouds -34.58  150.86
# 5        5     Buraydah      SA     66.20           clear sky  26.33   43.98
# 6        6     Kutoarjo      ID     61.00       broken clouds  -7.72  109.91
# 7        7    Cape Town      ZA     62.01    scattered clouds -33.93   18.42
# 8        9        Erzin      TR     61.00          few clouds  36.96   36.20
# 9       10         Faya      SA     62.60           clear sky  18.39   42.45
#
#                                 Hotel Name
# 0           Nanning Travelling With Hostel
# 1                    Hospitality Carnarvon
# 2                                  Tu Casa
# 3                           Pension Maro'i
# 4  Shellharbour Resort & Conference Centre
# 5                   Mövenpick Hotel Qassim
# 6                           Massagus Hotel
# 7        Southern Sun Waterfront Cape Town
# 8                             Artemis Otel
# 9                            مقبرة ال مجمل

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

hotel_info
# Out:
# ['\n<dl>\n<dt>Hotel Name</dt><dd>Nanning Travelling With Hostel</dd>\n<dt>City</dt><dd>Nanning</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 60.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospitality Carnarvon</dd>\n<dt>City</dt><dd>Carnarvon</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 71.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tu Casa</dd>\n<dt>City</dt><dd>East London</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>clear sky and 66.2 °F</dd>\n</dl>\n',
#  "\n<dl>\n<dt>Hotel Name</dt><dd>Pension Maro'i</dd>\n<dt>City</dt><dd>Rikitea</dd>\n<dt>Country</dt><dd>PF</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 74.03 °F</dd>\n</dl>\n",
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shellharbour Resort & Conference Centre</dd>\n<dt>City</dt><dd>Flinders</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 66.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mövenpick Hotel Qassim</dd>\n<dt>City</dt><dd>Buraydah</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Weather Description</dt><dd>clear sky and 66.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Massagus Hotel</dd>\n<dt>City</dt><dd>Kutoarjo</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>broken clouds and 61.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Southern Sun Waterfront Cape Town</dd>\n<dt>City</dt><dd>Cape Town</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 62.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Artemis Otel</dd>\n<dt>City</dt><dd>Erzin</dd>\n<dt>Country</dt><dd>TR</dd>\n<dt>Weather Description</dt><dd>few clouds and 61.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>مقبرة ال مجمل</dd>\n<dt>City</dt><dd>Faya</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Weather Description</dt><dd>clear sky and 62.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Keleti Beach Resort</dd>\n<dt>City</dt><dd>Vaini</dd>\n<dt>Country</dt><dd>TO</dd>\n<dt>Weather Description</dt><dd>broken clouds and 73.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>39 On Nile Guest House</dd>\n<dt>City</dt><dd>Port Elizabeth</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 62.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hilo Hawaiian Hotel</dd>\n<dt>City</dt><dd>Hilo</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>mist and 73.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotely Sariaka</dd>\n<dt>City</dt><dd>Ihosy</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Weather Description</dt><dd>broken clouds and 72.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel San Juan</dd>\n<dt>City</dt><dd>Coquimbo</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Weather Description</dt><dd>clear sky and 66.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>ASTON Jambi Hotel & Conference Center</dd>\n<dt>City</dt><dd>Jambi</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 73.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hostal La Casa de Melgar</dd>\n<dt>City</dt><dd>Mollendo</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 66.85 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Daydream Motel & Cottages</dd>\n<dt>City</dt><dd>Broken Hill</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 62.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Halyards Hotel</dd>\n<dt>City</dt><dd>Port Alfred</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>broken clouds and 64.27 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grage Hotel Bengkulu</dd>\n<dt>City</dt><dd>Bengkulu</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>light rain and 74.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Sebel Kiama Harbourside</dd>\n<dt>City</dt><dd>Kiama</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 66.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Dibbo areaمنطقة دبو</dd>\n<dt>City</dt><dd>Kutum</dd>\n<dt>Country</dt><dd>SD</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 69.84 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hospitality Esperance</dd>\n<dt>City</dt><dd>Esperance</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 62.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Surya Palace</dd>\n<dt>City</dt><dd>Chatakonda</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 68.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Gran Hotel Mar del Plata habitaciones</dd>\n<dt>City</dt><dd>Mar Del Plata</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>light rain and 66.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Jinjiang Inn Longyan Zhongshan Road Pedestrian Street</dd>\n<dt>City</dt><dd>Longyan</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Weather Description</dt><dd>clear sky and 60.55 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>tch tch</dd>\n<dt>City</dt><dd>Netanya</dd>\n<dt>Country</dt><dd>IL</dd>\n<dt>Weather Description</dt><dd>clear sky and 66.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel shri ji</dd>\n<dt>City</dt><dd>Baran</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>clear sky and 61.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Porto Santo & Spa</dd>\n<dt>City</dt><dd>Camacha</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Weather Description</dt><dd>few clouds and 66.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Las Casitas Santa Rosalia</dd>\n<dt>City</dt><dd>Santa Rosalia</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>clear sky and 72.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>InterContinental Riyadh</dd>\n<dt>City</dt><dd>Riyadh</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Weather Description</dt><dd>clear sky and 62.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ahipara Holiday Park</dd>\n<dt>City</dt><dd>Ahipara</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 66.29 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Espiritu Hotel</dd>\n<dt>City</dt><dd>Luganville</dd>\n<dt>Country</dt><dd>VU</dd>\n<dt>Weather Description</dt><dd>broken clouds and 71.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Taung Hlay Khar</dd>\n<dt>City</dt><dd>Myanaung</dd>\n<dt>Country</dt><dd>MM</dd>\n<dt>Weather Description</dt><dd>clear sky and 72.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel do Campo</dd>\n<dt>City</dt><dd>Ponta Do Sol</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Weather Description</dt><dd>few clouds and 66.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Shwe Phyu Hotel</dd>\n<dt>City</dt><dd>Myitkyina</dd>\n<dt>Country</dt><dd>MM</dd>\n<dt>Weather Description</dt><dd>broken clouds and 62.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Quinta da Meia Eira</dd>\n<dt>City</dt><dd>Ribeira Grande</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 60.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Maay Assa Hotel</dd>\n<dt>City</dt><dd>Adwa</dd>\n<dt>Country</dt><dd>ET</dd>\n<dt>Weather Description</dt><dd>broken clouds and 63.77 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Star inn Peniche</dd>\n<dt>City</dt><dd>Peniche</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 61.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vitthal Inn Pandharpur</dd>\n<dt>City</dt><dd>Pandharpur</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>broken clouds and 70.11 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hostal Las Lilas</dd>\n<dt>City</dt><dd>Lebu</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 60.75 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Marcial</dd>\n<dt>City</dt><dd>Naron</dd>\n<dt>Country</dt><dd>ES</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 60.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Musthafa Five Star Kiranam</dd>\n<dt>City</dt><dd>Farrukhnagar</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>mist and 68.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Galvarino</dd>\n<dt>City</dt><dd>Tocopilla</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Weather Description</dt><dd>broken clouds and 70.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hostal Morales</dd>\n<dt>City</dt><dd>Camana</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 68.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Residencial Karime</dd>\n<dt>City</dt><dd>Taltal</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Weather Description</dt><dd>broken clouds and 68.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Beachside Resort Whitianga</dd>\n<dt>City</dt><dd>Whitianga</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Weather Description</dt><dd>light rain and 64.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Gold Star International Hotel</dd>\n<dt>City</dt><dd>Bunia</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 64.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Lompoc</dd>\n<dt>City</dt><dd>Lompoc</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>clear sky and 60.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Ritz Apart Hotel</dd>\n<dt>City</dt><dd>La Paz</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 68.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Old Mill Hotel</dd>\n<dt>City</dt><dd>San Quintin</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>clear sky and 64.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Chik Chik Namibe</dd>\n<dt>City</dt><dd>Namibe</dd>\n<dt>Country</dt><dd>AO</dd>\n<dt>Weather Description</dt><dd>clear sky and 70.9 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lezíria Parque Hotel</dd>\n<dt>City</dt><dd>Sao Joao Dos Montes</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Weather Description</dt><dd>few clouds and 62.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel San Isidro Oficial</dd>\n<dt>City</dt><dd>Pisco</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Weather Description</dt><dd>clear sky and 73.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Barra</dd>\n<dt>City</dt><dd>Gafanha Da Encarnacao</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Weather Description</dt><dd>broken clouds and 60.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Haseeb Khan shatreng</dd>\n<dt>City</dt><dd>Kant</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 62.73 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Siang Guest House</dd>\n<dt>City</dt><dd>Pasighat</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>clear sky and 60.24 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Boutique Las Azucenas</dd>\n<dt>City</dt><dd>Constitucion</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Weather Description</dt><dd>clear sky and 63.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>HOTEL LA CASONA ITUANGO</dd>\n<dt>City</dt><dd>Ituango</dd>\n<dt>Country</dt><dd>CO</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 70.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Valle Aridane</dd>\n<dt>City</dt><dd>Los Llanos De Aridane</dd>\n<dt>Country</dt><dd>ES</dd>\n<dt>Weather Description</dt><dd>clear sky and 73.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Port Lincoln Hotel</dd>\n<dt>City</dt><dd>Port Lincoln</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>light rain and 60.94 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sur Plaza Hotel</dd>\n<dt>City</dt><dd>Sur</dd>\n<dt>Country</dt><dd>OM</dd>\n<dt>Weather Description</dt><dd>clear sky and 74.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Haji laloo memon house</dd>\n<dt>City</dt><dd>Keti Bandar</dd>\n<dt>Country</dt><dd>PK</dd>\n<dt>Weather Description</dt><dd>clear sky and 67.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>SpringHill Suites by Marriott Las Cruces</dd>\n<dt>City</dt><dd>Las Cruces</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 62.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>dyd -mar Hotel</dd>\n<dt>City</dt><dd>Necochea</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 72.12 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Rumah mbah Jamah</dd>\n<dt>City</dt><dd>Japura</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 72.81 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Juvinal Martin</dd>\n<dt>City</dt><dd>Airai</dd>\n<dt>Country</dt><dd>TL</dd>\n<dt>Weather Description</dt><dd>clear sky and 61.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Pacifica Lighthouse, Trademark Collection by Wyndham</dd>\n<dt>City</dt><dd>Pacifica</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>clear sky and 60.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Memory</dd>\n<dt>City</dt><dd>Akyab</dd>\n<dt>Country</dt><dd>MM</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 73.74 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Punta León</dd>\n<dt>City</dt><dd>Rawson</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 68.7 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Green Valley</dd>\n<dt>City</dt><dd>Rosetta</dd>\n<dt>Country</dt><dd>EG</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 68.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Lefika Lodge</dd>\n<dt>City</dt><dd>Phuthaditjhaba</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>clear sky and 63.18 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sandpiper Motel</dd>\n<dt>City</dt><dd>Ulladulla</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 61.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Restaurant Turístico Casablanca</dd>\n<dt>City</dt><dd>Hualmay</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Weather Description</dt><dd>few clouds and 69.15 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mini Hotel Central</dd>\n<dt>City</dt><dd>Victoria</dd>\n<dt>Country</dt><dd>HK</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 73.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Vitasoa</dd>\n<dt>City</dt><dd>Antalaha</dd>\n<dt>Country</dt><dd>MG</dd>\n<dt>Weather Description</dt><dd>light rain and 72.91 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa Laguna, Bed & Breakfast</dd>\n<dt>City</dt><dd>Guerrero Negro</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>clear sky and 68.83 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Terramar</dd>\n<dt>City</dt><dd>Talcahuano</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Weather Description</dt><dd>few clouds and 68.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OlusHome</dd>\n<dt>City</dt><dd>Gat</dd>\n<dt>Country</dt><dd>IL</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 64.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Protea Hotel by Marriott Bloemfontein</dd>\n<dt>City</dt><dd>Bloemfontein</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>clear sky and 64.4 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Oyster Bay House Rental</dd>\n<dt>City</dt><dd>Kruisfontein</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 61.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>奄美ポートタワーホテル</dd>\n<dt>City</dt><dd>Naze</dd>\n<dt>Country</dt><dd>JP</dd>\n<dt>Weather Description</dt><dd>few clouds and 69.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>محمد هادي ال فطيح</dd>\n<dt>City</dt><dd>Najran</dd>\n<dt>Country</dt><dd>SA</dd>\n<dt>Weather Description</dt><dd>clear sky and 66.2 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Mrs Luis Guest House</dd>\n<dt>City</dt><dd>Lampang</dd>\n<dt>Country</dt><dd>TH</dd>\n<dt>Weather Description</dt><dd>clear sky and 69.66 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Yuehai Hotel</dd>\n<dt>City</dt><dd>Jieshi</dd>\n<dt>Country</dt><dd>CN</dd>\n<dt>Weather Description</dt><dd>clear sky and 68.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Village Mianda Mutole</dd>\n<dt>City</dt><dd>Kabinda</dd>\n<dt>Country</dt><dd>CD</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 67.86 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Broadwater Mariner Resort</dd>\n<dt>City</dt><dd>Geraldton</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 68.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Sri Venkateshwara Wood Carving works</dd>\n<dt>City</dt><dd>Sidlaghatta</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>mist and 68.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Briliá</dd>\n<dt>City</dt><dd>Chimbote</dd>\n<dt>Country</dt><dd>PE</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 68.67 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>OYO 3177 Wisma Lintang</dd>\n<dt>City</dt><dd>Metro</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>light rain and 74.62 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Kou-Bugny</dd>\n<dt>City</dt><dd>Vao</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Weather Description</dt><dd>clear sky and 74.3 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Aquarius Boutique Hotel Sampit</dd>\n<dt>City</dt><dd>Sampit</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 74.16 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Tein Phyu Hlwar</dd>\n<dt>City</dt><dd>Kyaukse</dd>\n<dt>Country</dt><dd>MM</dd>\n<dt>Weather Description</dt><dd>broken clouds and 67.68 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Casa De Thompson</dd>\n<dt>City</dt><dd>Maneadero</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>clear sky and 62.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Daito Guest House</dd>\n<dt>City</dt><dd>Kokoda</dd>\n<dt>Country</dt><dd>PG</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 72.59 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Direk Hotel</dd>\n<dt>City</dt><dd>Lefka</dd>\n<dt>Country</dt><dd>CY</dd>\n<dt>Weather Description</dt><dd>few clouds and 62.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Fanta Coin Snack- Bar Auberge</dd>\n<dt>City</dt><dd>Foumbot</dd>\n<dt>Country</dt><dd>CM</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 69.28 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Parkview Motel</dd>\n<dt>City</dt><dd>Dargaville</dd>\n<dt>Country</dt><dd>NZ</dd>\n<dt>Weather Description</dt><dd>light rain and 65.35 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>hotel paseo madrid</dd>\n<dt>City</dt><dd>Atocha</dd>\n<dt>Country</dt><dd>BO</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 69.6 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Camping de Tipenga</dd>\n<dt>City</dt><dd>Pouembout</dd>\n<dt>Country</dt><dd>NC</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 72.46 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Santa Rita</dd>\n<dt>City</dt><dd>Barra Da Estiva</dd>\n<dt>Country</dt><dd>BR</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 73.44 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La casa di Jo</dd>\n<dt>City</dt><dd>Vittoria</dd>\n<dt>Country</dt><dd>IT</dd>\n<dt>Weather Description</dt><dd>few clouds and 60.8 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Apollon Motor Inn</dd>\n<dt>City</dt><dd>Victor Harbor</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 62.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La Quinta Inn & Suites by Wyndham Stephenville</dd>\n<dt>City</dt><dd>Stephenville</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 73.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>THE BABBU PARADISE</dd>\n<dt>City</dt><dd>Bhatapara</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 62.13 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Grand Zion Garden Resort Hotel</dd>\n<dt>City</dt><dd>Tabuk</dd>\n<dt>Country</dt><dd>PH</dd>\n<dt>Weather Description</dt><dd>clear sky and 69.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Napakuang Resort</dd>\n<dt>City</dt><dd>Phonhong</dd>\n<dt>Country</dt><dd>LA</dd>\n<dt>Weather Description</dt><dd>broken clouds and 72.54 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Khách Sạn Mường Thanh Luxury Cà Mau</dd>\n<dt>City</dt><dd>Ca Mau</dd>\n<dt>Country</dt><dd>VN</dd>\n<dt>Weather Description</dt><dd>light rain and 74.64 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Molika Springs Motel</dd>\n<dt>City</dt><dd>Moree</dd>\n<dt>Country</dt><dd>AU</dd>\n<dt>Weather Description</dt><dd>clear sky and 68.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Bent tree subdivision</dd>\n<dt>City</dt><dd>Rincon</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>few clouds and 66.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>WAMY RESIDENCE HOTEL</dd>\n<dt>City</dt><dd>Makokou</dd>\n<dt>Country</dt><dd>GA</dd>\n<dt>Weather Description</dt><dd>clear sky and 72.34 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Holiday Inn Express Antofagasta</dd>\n<dt>City</dt><dd>Antofagasta</dd>\n<dt>Country</dt><dd>CL</dd>\n<dt>Weather Description</dt><dd>broken clouds and 69.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Asrama Polisi Polsek Loajanan Res Kukar</dd>\n<dt>City</dt><dd>Loa Janan</dd>\n<dt>Country</dt><dd>ID</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 73.92 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Ritz-Carlton, Half Moon Bay</dd>\n<dt>City</dt><dd>Half Moon Bay</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>mist and 60.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Americas Best Value Inn Decatur, GA</dd>\n<dt>City</dt><dd>Gresham Park</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>broken clouds and 60.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Arribas Sintra Hotel</dd>\n<dt>City</dt><dd>Colares</dd>\n<dt>Country</dt><dd>PT</dd>\n<dt>Weather Description</dt><dd>scattered clouds and 62.01 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>La Quinta Inn & Suites by Wyndham Irvine Spectrum</dd>\n<dt>City</dt><dd>Orange</dd>\n<dt>Country</dt><dd>US</dd>\n<dt>Weather Description</dt><dd>few clouds and 66.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>The Lillies Guesthouse</dd>\n<dt>City</dt><dd>Reitz</dd>\n<dt>Country</dt><dd>ZA</dd>\n<dt>Weather Description</dt><dd>clear sky and 63.14 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Santa Rosa</dd>\n<dt>City</dt><dd>Olavarria</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>light rain and 64.99 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Almadiafah</dd>\n<dt>City</dt><dd>Talkha</dd>\n<dt>Country</dt><dd>EG</dd>\n<dt>Weather Description</dt><dd>clear sky and 62.51 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>บ้านเจเน็ต คอมพิวเตอร์</dd>\n<dt>City</dt><dd>Sawang Daen Din</dd>\n<dt>Country</dt><dd>TH</dd>\n<dt>Weather Description</dt><dd>clear sky and 72.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Austral Hotel</dd>\n<dt>City</dt><dd>Comodoro Rivadavia</dd>\n<dt>Country</dt><dd>AR</dd>\n<dt>Weather Description</dt><dd>broken clouds and 68.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>sangil roadways</dd>\n<dt>City</dt><dd>Harur</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>overcast clouds and 70.36 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Hotel Estancia del Vaquero</dd>\n<dt>City</dt><dd>Ocampo</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>clear sky and 70.88 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Luis Guillermo García Medina</dd>\n<dt>City</dt><dd>Benjamin Hill</dd>\n<dt>Country</dt><dd>MX</dd>\n<dt>Weather Description</dt><dd>clear sky and 72.0 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Eng Hiirey House</dd>\n<dt>City</dt><dd>Odweyne</dd>\n<dt>Country</dt><dd>SO</dd>\n<dt>Weather Description</dt><dd>broken clouds and 68.5 °F</dd>\n</dl>\n',
#  '\n<dl>\n<dt>Hotel Name</dt><dd>Dehing Guest House</dd>\n<dt>City</dt><dd>Margherita</dd>\n<dt>Country</dt><dd>IN</dd>\n<dt>Weather Description</dt><dd>clear sky and 60.21 °F</dd>\n</dl>\n']

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[(vacation_df['City'] == 'Gafanha Da Encarnacao')]
vacation_end = vacation_df.loc[(vacation_df['City'] == 'Gafanha Da Encarnacao')]
vacation_stop1 = vacation_df.loc[(vacation_df['City'] == 'Peniche')]
vacation_stop2 = vacation_df.loc[(vacation_df['City'] == 'Sao Joao Dos Montes')] 
vacation_stop3 = vacation_df.loc[(vacation_df['City'] == 'Colares')]

# %%
tuple(vacation_start[['Lat','Lng']].to_numpy()[0])
# Out:
# (40.62, -8.73)

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = tuple(vacation_start[['Lat','Lng']].to_numpy()[0])
end = tuple(vacation_end[['Lat','Lng']].to_numpy()[0])
stop1 = tuple(vacation_stop1[['Lat','Lng']].to_numpy()[0])
stop2 = tuple(vacation_stop2[['Lat','Lng']].to_numpy()[0])
stop3 = tuple(vacation_stop3[['Lat','Lng']].to_numpy()[0])

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

fig = gmaps.figure()
vacation_itinerary = gmaps.directions_layer(start, end, [stop1, stop2, stop3])
fig.add_layer(vacation_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID                   City Country  Max Temp Current Description  \
# 0       59  Gafanha Da Encarnacao      PT     60.01       broken clouds
# 1       40                Peniche      PT     61.00     overcast clouds
# 2       56    Sao Joao Dos Montes      PT     62.60          few clouds
# 3      126                Colares      PT     62.01    scattered clouds
#
#      Lat   Lng              Hotel Name
# 0  40.62 -8.73             Hotel Barra
# 1  39.36 -9.38  Hotel Star inn Peniche
# 2  38.94 -9.02    Lezíria Parque Hotel
# 3  38.80 -9.45    Arribas Sintra Hotel

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description} and {Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]
locations
# Out:
#      Lat   Lng
# 0  40.62 -8.73
# 1  39.36 -9.38
# 2  38.94 -9.02
# 3  38.80 -9.45

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(40.0, -8.0), zoom_level=7)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(marker_layer)


# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
