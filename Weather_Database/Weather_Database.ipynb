# %%
import pandas as pd
import numpy as np

#imports the previous directory for config.py
import sys
sys.path.insert(1, '../')

from citipy import citipy
from config import weather_api_key
import requests
from datetime import datetime

# %%
# Create 2000 latitudes and longitudes, and use the .zip function to create pairs, then cast that to a list

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# %%
# Use citipy to find the nearest city for each coordinate and add each unique value to a list

cities = []
for coordinate in coordinates:
    curr_city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if curr_city not in cities:
        cities.append(curr_city)
        
cities
# Out:
# ['pevek',
#  'kavieng',
#  'nanning',
#  'carnarvon',
#  'arraial do cabo',
#  'east london',
#  'bredasdorp',
#  'tasiilaq',
#  'nsanje',
#  'cabo san lucas',
#  'dikson',
#  'rikitea',
#  'flinders',
#  'buraydah',
#  'bluff',
#  'thompson',
#  'kutoarjo',
#  'tsihombe',
#  'port hardy',
#  'cape town',
#  'jamestown',
#  'ongandjera',
#  'mahebourg',
#  'saleaula',
#  'cravo norte',
#  'vaitupu',
#  'butaritari',
#  'kapaa',
#  'kidal',
#  'mataura',
#  'beyneu',
#  'meulaboh',
#  'provideniya',
#  'nikolskoye',
#  'dianopolis',
#  'torbay',
#  'erzin',
#  'neiafu',
#  'labytnangi',
#  'faya',
#  'vaini',
#  'port elizabeth',
#  'haines junction',
#  'khatanga',
#  'sitka',
#  'hobart',
#  'severo-kurilsk',
#  'fairview',
#  'belmonte',
#  'cumberland',
#  'korla',
#  'sohatu',
#  'hilo',
#  'albany',
#  'arman',
#  'ihosy',
#  'tumannyy',
#  'vila franca do campo',
#  'belushya guba',
#  'lodwar',
#  'berlevag',
#  'ushuaia',
#  'atuona',
#  'chuy',
#  'coquimbo',
#  'avarua',
#  'dunedin',
#  'grand river south east',
#  'baykit',
#  'tonantins',
#  'juneau',
#  'adrar',
#  'puerto ayora',
#  'nanortalik',
#  'cagayan de tawi-tawi',
#  'jambi',
#  'mollendo',
#  'ardistan',
#  'taolanaro',
#  'jinchang',
#  'narsaq',
#  'cidreira',
#  'henties bay',
#  'kangaatsiaq',
#  'broken hill',
#  'amderma',
#  'port alfred',
#  'tuatapere',
#  'aldan',
#  'tuchola',
#  'poso',
#  'biak',
#  'bengkulu',
#  'yar-sale',
#  'bafra',
#  'olafsvik',
#  'saskylakh',
#  'mercedes',
#  'iqaluit',
#  'kiama',
#  'the valley',
#  'kutum',
#  'beira',
#  'barentsburg',
#  'kodiak',
#  'castanos',
#  'sentyabrskiy',
#  'sabang',
#  'avallon',
#  'rioja',
#  'punta arenas',
#  'padang',
#  'kalabo',
#  'moju',
#  'esperance',
#  'ewa beach',
#  'berberati',
#  'luderitz',
#  'aripuana',
#  'senno',
#  'sibolga',
#  'yellowknife',
#  'longyearbyen',
#  'chatakonda',
#  'north bend',
#  'mount isa',
#  'saint-philippe',
#  'porto novo',
#  'norman wells',
#  'thinadhoo',
#  'saint anthony',
#  'new norfolk',
#  'upernavik',
#  'mar del plata',
#  'maceio',
#  'lavrentiya',
#  'nizhneyansk',
#  'busselton',
#  'xai-xai',
#  'belyy yar',
#  'longyan',
#  'netanya',
#  'baran',
#  'moses lake',
#  'tortoli',
#  'poum',
#  'louisbourg',
#  'belaya gora',
#  'castro',
#  'barawe',
#  'vaitape',
#  'kozhva',
#  'qaanaaq',
#  'rocha',
#  'conceicao do araguaia',
#  'camacha',
#  'santa rosalia',
#  'omsukchan',
#  'chara',
#  'riyadh',
#  'ahipara',
#  'cayenne',
#  'luganville',
#  'myanaung',
#  'hithadhoo',
#  'praia',
#  'freeport',
#  'pagegiai',
#  'dobrinje',
#  'ponta do sol',
#  'cabinda',
#  'illoqqortoormiut',
#  'hermanus',
#  'matelandia',
#  'mys shmidta',
#  'hambantota',
#  'myitkyina',
#  'zhoucheng',
#  'ribeira grande',
#  'gamba',
#  'nome',
#  'warka',
#  'adwa',
#  'hamilton',
#  'isangel',
#  'leshukonskoye',
#  'mayor pablo lagerenza',
#  'ola',
#  'marawi',
#  'darab',
#  'peniche',
#  'attawapiskat',
#  'codrington',
#  'pandharpur',
#  'cedar rapids',
#  'nioro',
#  'tamale',
#  'varca',
#  'lebu',
#  'sinnamary',
#  'havre-saint-pierre',
#  'naron',
#  'mogochin',
#  'ferkessedougou',
#  'beloha',
#  'husavik',
#  'farrukhnagar',
#  'boende',
#  'tocopilla',
#  'la grande',
#  'purpe',
#  'hudson bay',
#  'camana',
#  'barrow',
#  'san angelo',
#  'fairbanks',
#  'missoula',
#  'monterey',
#  'sandnessjoen',
#  'taltal',
#  'garden city',
#  'itarema',
#  'tabialan',
#  'bathsheba',
#  'whitianga',
#  'pak phanang',
#  'hofn',
#  'clyde river',
#  'karratha',
#  'souillac',
#  'bunia',
#  'vila',
#  'bejuco',
#  'kailua',
#  'bari',
#  'katsuura',
#  'lompoc',
#  'bafoulabe',
#  'tucurui',
#  'mana',
#  'deputatskiy',
#  'ossora',
#  'praya',
#  'mount gambier',
#  'rio grande city',
#  'jiuquan',
#  'leningradskiy',
#  'la paz',
#  'bognor regis',
#  'lorengau',
#  'dingle',
#  'san quintin',
#  'sao filipe',
#  'chokurdakh',
#  'waingapu',
#  'mehriz',
#  'bima',
#  'acapulco',
#  'tautira',
#  'warqla',
#  'mecca',
#  'artyk',
#  'flin flon',
#  'namibe',
#  'kamenskoye',
#  'smoky lake',
#  'sao joao dos montes',
#  'avera',
#  'pisco',
#  'te anau',
#  'tiksi',
#  'hasaki',
#  'kaitangata',
#  'newark',
#  'saldanha',
#  'saint george',
#  'suoyarvi',
#  'gafanha da encarnacao',
#  'taoudenni',
#  'kant',
#  'heyang',
#  'pasighat',
#  'constitucion',
#  'mattru',
#  'zeya',
#  'nexo',
#  'salalah',
#  'brae',
#  'ituango',
#  'mtwara',
#  'irbeyskoye',
#  'eidfjord',
#  'vardo',
#  'requena',
#  'los llanos de aridane',
#  'tianpeng',
#  'port lincoln',
#  'waw',
#  'linqiong',
#  'elko',
#  'sur',
#  'burgeo',
#  'birchis',
#  'pizhanka',
#  'kamaishi',
#  'plattsburgh',
#  'ler',
#  'pandan',
#  'nouakchott',
#  'sambava',
#  'barcelos',
#  'south lake tahoe',
#  'sterling',
#  'dali',
#  'kyshtovka',
#  'keti bandar',
#  'san patricio',
#  'kuznechnoye',
#  'san juan',
#  'bethel',
#  'san luis',
#  'las cruces',
#  'paradwip',
#  'hay river',
#  'lazaro cardenas',
#  'busdi',
#  'zavolzhsk',
#  'laramie',
#  'necochea',
#  'mutsu',
#  'japura',
#  'raurkela',
#  'airai',
#  'hirado',
#  'pacifica',
#  'fare',
#  'nenjiang',
#  'wufeng',
#  'paamiut',
#  'akyab',
#  'bara',
#  'tysons corner',
#  'shengjin',
#  'bayir',
#  'nguiu',
#  'rawson',
#  'shakawe',
#  'darnetal',
#  'tuktoyaktuk',
#  'fomboni',
#  'rosetta',
#  'phuthaditjhaba',
#  'pemangkat',
#  'mauguio',
#  'chapais',
#  'faanui',
#  'ulladulla',
#  'dong hoi',
#  'marshfield',
#  'powell river',
#  'hualmay',
#  'yatou',
#  'nantucket',
#  'darhan',
#  'shimanovsk',
#  'monitos',
#  'balykshi',
#  'kulhudhuffushi',
#  'victoria',
#  'buenos aires',
#  'kununurra',
#  'caravelas',
#  'rassvet',
#  'vulcan',
#  'touros',
#  'antalaha',
#  'sao geraldo do araguaia',
#  'talnakh',
#  'nouadhibou',
#  'chifeng',
#  'lagoa',
#  'mehamn',
#  'bargal',
#  'fort nelson',
#  'mergui',
#  'skagastrond',
#  'shkotovo-26',
#  'kilindoni',
#  'terney',
#  'makakilo city',
#  'guerrero negro',
#  'talcahuano',
#  'shimsk',
#  'celestun',
#  'kayerkan',
#  'iskateley',
#  'ambilobe',
#  'high prairie',
#  'satitoa',
#  'dingtao',
#  'sjenica',
#  'gat',
#  'agbor',
#  'bloemfontein',
#  'kruisfontein',
#  'naze',
#  'kotdwara',
#  'herat',
#  'fortuna',
#  'altamira',
#  'svetlogorsk',
#  'georgetown',
#  'calama',
#  'bambous virieux',
#  'desna',
#  'pesochnoye',
#  'galveston',
#  'salinopolis',
#  'alyangula',
#  'alofi',
#  'weyburn',
#  'pangai',
#  'domoni',
#  'san lazaro',
#  'port hedland',
#  'kestel',
#  'bon air',
#  'paraibano',
#  'najran',
#  'mihailesti',
#  'verkhnyaya inta',
#  'lampang',
#  'blackfoot',
#  'lara',
#  'seymchan',
#  'jieshi',
#  'kabinda',
#  'iesolo',
#  'geraldton',
#  'manokwari',
#  'shahrud',
#  'kieta',
#  'glendive',
#  'ilulissat',
#  'okhotsk',
#  'sidlaghatta',
#  'erenhot',
#  'bramming',
#  'kahului',
#  'lolua',
#  'sorvag',
#  'port-gentil',
#  'bereda',
#  'laela',
#  'marcona',
#  'oussouye',
#  'sao joao da barra',
#  'chimbote',
#  'gigmoto',
#  'metro',
#  'ulaanbaatar',
#  'xinqing',
#  'gueret',
#  'kargasok',
#  'vao',
#  'grand gaube',
#  'port blair',
#  'goundam',
#  'sembakung',
#  'sarakhs',
#  'dinard',
#  'lucea',
#  'aleksandrovskiy zavod',
#  'vertientes',
#  'bakchar',
#  'sampit',
#  'ondarroa',
#  'wanaka',
#  'zhigansk',
#  'kyaukse',
#  'orchard homes',
#  'yulara',
#  'grong',
#  'luoyang',
#  'hokitika',
#  'maneadero',
#  'axim',
#  'idrinskoye',
#  'safranbolu',
#  'inirida',
#  'key west',
#  'broadstairs',
#  'yablonovo',
#  'san andres',
#  'babaeski',
#  'tual',
#  'carutapera',
#  'batticaloa',
#  'viedma',
#  'otjiwarongo',
#  'ligayan',
#  'komsomolskiy',
#  'san cristobal',
#  'kokoda',
#  'sao jose da coroa grande',
#  'biu',
#  'prince george',
#  'cherskiy',
#  'opuwo',
#  'beringovskiy',
#  'palabuhanratu',
#  'lefka',
#  'mujiayingzi',
#  'skelleftea',
#  'mackenzie',
#  'bairiki',
#  'mont-de-marsan',
#  'matara',
#  'maryville',
#  'roberto payan',
#  'serebryanyy bor',
#  'asau',
#  'saint-denis',
#  'foumbot',
#  'maniitsoq',
#  'maldonado',
#  'tolaga bay',
#  'dargaville',
#  'bubaque',
#  'bemidji',
#  'westport',
#  'anshan',
#  'libreville',
#  'calais',
#  'maniwaki',
#  'atocha',
#  'nelson bay',
#  'diamantino',
#  'pingliang',
#  'kromy',
#  'naqadeh',
#  'biltine',
#  'rungata',
#  'maebaru',
#  'mnogovershinnyy',
#  'sobolevo',
#  'vilhena',
#  'rundu',
#  'lagunas',
#  'yoichi',
#  'rudnytsya',
#  'yumen',
#  'batagay-alyta',
#  'sayat',
#  'chore',
#  'west fargo',
#  'hami',
#  'meyungs',
#  'lake charles',
#  'pouembout',
#  'asekeyevo',
#  'college',
#  'barra da estiva',
#  'babushkin',
#  'ambon',
#  'vittoria',
#  'tromso',
#  'shelburne',
#  'palmas bellas',
#  'shingu',
#  'victor harbor',
#  'marinette',
#  'inuvik',
#  'kirakira',
#  'zhanatas',
#  'stephenville',
#  'lahr',
#  'rabo de peixe',
#  'lasa',
#  'ust-uda',
#  'manicore',
#  'grafton',
#  'tessalit',
#  'tilichiki',
#  'jaciara',
#  'coahuayana',
#  'roanne',
#  'bhatapara',
#  'mrirt',
#  'saint-joseph',
#  'vostok',
#  'ponta delgada',
#  'skagen',
#  'hihifo',
#  'puerto colombia',
#  'baruun-urt',
#  'lakes entrance',
#  'passo fundo',
#  'dwarka',
#  'galgani',
#  'pocone',
#  'port macquarie',
#  'qaqortoq',
#  'wroclaw',
#  'marica',
#  'melilla',
#  'quelimane',
#  'quesnel',
#  'saundatti yellamma',
#  'tabuk',
#  'ningxiang',
#  'phonhong',
#  'ca mau',
#  'lubyany',
#  'mogadishu',
#  'meridian',
#  'pangnirtung',
#  'moree',
#  'rincon',
#  'turukhansk',
#  'aklavik',
#  'nordlingen',
#  'bulgan',
#  'seydisehir',
#  'makokou',
#  'antofagasta',
#  'teguldet',
#  'wahiawa',
#  'lamar',
#  'marv dasht',
#  'bonavista',
#  'boa vista',
#  'villazon',
#  'damghan',
#  'fukue',
#  'dongsheng',
#  'dolbeau',
#  'la ronge',
#  'vestmanna',
#  'loa janan',
#  'bambanglipuro',
#  'mahadday weyne',
#  'sarangani',
#  'zarand',
#  'zhezkazgan',
#  'tuggurt',
#  'port augusta',
#  'auki',
#  'gravdal',
#  'hinatuan',
#  'nokaneng',
#  'kirgiz-miyaki',
#  'rio gallegos',
#  'alekseyevsk',
#  'san policarpo',
#  'half moon bay',
#  'dahra',
#  'quirinopolis',
#  'gresham park',
#  'komsomolskoye',
#  'gao',
#  'kalmunai',
#  'nara',
#  'nemuro',
#  'samusu',
#  'muzhi',
#  'filadelfia',
#  'tarquinia',
#  'sesheke',
#  'tuy hoa',
#  'walla walla',
#  'ayagoz',
#  'wageningen',
#  'ozgon',
#  'shizunai',
#  'havelock',
#  'manitouwadge',
#  'zyryanka',
#  'huilong',
#  'koungou',
#  'wulanhaote',
#  'veinticinco de mayo',
#  'sungai padi',
#  'baherden',
#  'abu zabad',
#  'karatau',
#  'samarai',
#  'colares',
#  'kabalo',
#  'cururupu',
#  'anito',
#  'wawa',
#  'kadyy',
#  'orange',
#  'houma',
#  'santa isabel',
#  'noumea',
#  'nhulunbuy',
#  'reitz',
#  'ziarat',
#  'black river',
#  'quzhou',
#  'jumla',
#  'inhambane',
#  'olavarria',
#  'mednogorsk',
#  'cumaribo',
#  'siay',
#  'talkha',
#  'borovskoy',
#  'betsiamites',
#  'tartagal',
#  'sayyan',
#  'kudat',
#  'nchelenge',
#  'pontianak',
#  'ahuimanu',
#  'sawang daen din',
#  'bajo baudo',
#  'bucerias',
#  'pochutla',
#  'jinan',
#  'sinkat',
#  'comodoro rivadavia',
#  'sringeri',
#  'coihaique',
#  'hobyo',
#  'harur',
#  'bad oldesloe',
#  'cap malheureux',
#  'xining',
#  'rafai',
#  'suntar',
#  'temaraia',
#  'ocampo',
#  'kurumkan',
#  'lourdes',
#  'kihei',
#  'burica',
#  'benjamin hill',
#  'kropotkin',
#  'isabela',
#  'odweyne',
#  'chumikan',
#  'fonte boa',
#  'zhangye',
#  'morant bay',
#  'buchanan',
#  'kuytun',
#  'barbar',
#  'oistins',
#  'ust-kamchatsk',
#  'margherita',
#  'nuuk',
#  'kamenka',
#  'birnin kebbi',
#  'altay',
#  'alice town',
#  'satun',
#  'kuryk',
#  'mahajanga']

# %%
city_data = []
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
record_count = 1
set_count = 1


print("Beginning Data Retrieval     ")
print("-----------------------------")

for i, city in enumerate(cities):
    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    city_url = url + "&q=" + city.replace(" ", "+")

    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    record_count += 1

    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]['description']
        # # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description})

# # If an error is experienced, skip the city.
    except:
        print(f"{city} not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pevek
# Processing Record 2 of Set 1 | kavieng
# Processing Record 3 of Set 1 | nanning
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | tasiilaq
# Processing Record 9 of Set 1 | nsanje
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | flinders
# Processing Record 14 of Set 1 | buraydah
# Processing Record 15 of Set 1 | bluff
# Processing Record 16 of Set 1 | thompson
# Processing Record 17 of Set 1 | kutoarjo
# Processing Record 18 of Set 1 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 19 of Set 1 | port hardy
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | ongandjera
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | saleaula
# saleaula not found. Skipping...
# Processing Record 25 of Set 1 | cravo norte
# Processing Record 26 of Set 1 | vaitupu
# vaitupu not found. Skipping...
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | kapaa
# Processing Record 29 of Set 1 | kidal
# Processing Record 30 of Set 1 | mataura
# Processing Record 31 of Set 1 | beyneu
# Processing Record 32 of Set 1 | meulaboh
# Processing Record 33 of Set 1 | provideniya
# Processing Record 34 of Set 1 | nikolskoye
# Processing Record 35 of Set 1 | dianopolis
# dianopolis not found. Skipping...
# Processing Record 36 of Set 1 | torbay
# Processing Record 37 of Set 1 | erzin
# Processing Record 38 of Set 1 | neiafu
# Processing Record 39 of Set 1 | labytnangi
# Processing Record 40 of Set 1 | faya
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | port elizabeth
# Processing Record 43 of Set 1 | haines junction
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | sitka
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | severo-kurilsk
# Processing Record 48 of Set 1 | fairview
# Processing Record 49 of Set 1 | belmonte
# Processing Record 50 of Set 1 | cumberland
# Processing Record 1 of Set 2 | korla
# Processing Record 2 of Set 2 | sohatu
# Processing Record 3 of Set 2 | hilo
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | arman
# Processing Record 6 of Set 2 | ihosy
# Processing Record 7 of Set 2 | tumannyy
# tumannyy not found. Skipping...
# Processing Record 8 of Set 2 | vila franca do campo
# Processing Record 9 of Set 2 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 10 of Set 2 | lodwar
# Processing Record 11 of Set 2 | berlevag
# Processing Record 12 of Set 2 | ushuaia
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | coquimbo
# Processing Record 16 of Set 2 | avarua
# Processing Record 17 of Set 2 | dunedin
# Processing Record 18 of Set 2 | grand river south east
# grand river south east not found. Skipping...
# Processing Record 19 of Set 2 | baykit
# Processing Record 20 of Set 2 | tonantins
# Processing Record 21 of Set 2 | juneau
# Processing Record 22 of Set 2 | adrar
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | nanortalik
# Processing Record 25 of Set 2 | cagayan de tawi-tawi
# cagayan de tawi-tawi not found. Skipping...
# Processing Record 26 of Set 2 | jambi
# Processing Record 27 of Set 2 | mollendo
# Processing Record 28 of Set 2 | ardistan
# ardistan not found. Skipping...
# Processing Record 29 of Set 2 | taolanaro
# taolanaro not found. Skipping...
# Processing Record 30 of Set 2 | jinchang
# Processing Record 31 of Set 2 | narsaq
# Processing Record 32 of Set 2 | cidreira
# Processing Record 33 of Set 2 | henties bay
# Processing Record 34 of Set 2 | kangaatsiaq
# Processing Record 35 of Set 2 | broken hill
# Processing Record 36 of Set 2 | amderma
# amderma not found. Skipping...
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | tuatapere
# Processing Record 39 of Set 2 | aldan
# Processing Record 40 of Set 2 | tuchola
# Processing Record 41 of Set 2 | poso
# Processing Record 42 of Set 2 | biak
# Processing Record 43 of Set 2 | bengkulu
# Processing Record 44 of Set 2 | yar-sale
# Processing Record 45 of Set 2 | bafra
# Processing Record 46 of Set 2 | olafsvik
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | mercedes
# Processing Record 49 of Set 2 | iqaluit
# Processing Record 50 of Set 2 | kiama
# Processing Record 1 of Set 3 | the valley
# Processing Record 2 of Set 3 | kutum
# Processing Record 3 of Set 3 | beira
# Processing Record 4 of Set 3 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 5 of Set 3 | kodiak
# Processing Record 6 of Set 3 | castanos
# Processing Record 7 of Set 3 | sentyabrskiy
# sentyabrskiy not found. Skipping...
# Processing Record 8 of Set 3 | sabang
# Processing Record 9 of Set 3 | avallon
# Processing Record 10 of Set 3 | rioja
# Processing Record 11 of Set 3 | punta arenas
# Processing Record 12 of Set 3 | padang
# Processing Record 13 of Set 3 | kalabo
# Processing Record 14 of Set 3 | moju
# Processing Record 15 of Set 3 | esperance
# Processing Record 16 of Set 3 | ewa beach
# Processing Record 17 of Set 3 | berberati
# Processing Record 18 of Set 3 | luderitz
# Processing Record 19 of Set 3 | aripuana
# Processing Record 20 of Set 3 | senno
# Processing Record 21 of Set 3 | sibolga
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | chatakonda
# Processing Record 25 of Set 3 | north bend
# Processing Record 26 of Set 3 | mount isa
# Processing Record 27 of Set 3 | saint-philippe
# Processing Record 28 of Set 3 | porto novo
# Processing Record 29 of Set 3 | norman wells
# Processing Record 30 of Set 3 | thinadhoo
# Processing Record 31 of Set 3 | saint anthony
# Processing Record 32 of Set 3 | new norfolk
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | mar del plata
# Processing Record 35 of Set 3 | maceio
# Processing Record 36 of Set 3 | lavrentiya
# Processing Record 37 of Set 3 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 38 of Set 3 | busselton
# Processing Record 39 of Set 3 | xai-xai
# Processing Record 40 of Set 3 | belyy yar
# Processing Record 41 of Set 3 | longyan
# Processing Record 42 of Set 3 | netanya
# Processing Record 43 of Set 3 | baran
# Processing Record 44 of Set 3 | moses lake
# Processing Record 45 of Set 3 | tortoli
# Processing Record 46 of Set 3 | poum
# Processing Record 47 of Set 3 | louisbourg
# louisbourg not found. Skipping...
# Processing Record 48 of Set 3 | belaya gora
# Processing Record 49 of Set 3 | castro
# Processing Record 50 of Set 3 | barawe
# barawe not found. Skipping...
# Processing Record 1 of Set 4 | vaitape
# Processing Record 2 of Set 4 | kozhva
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | rocha
# Processing Record 5 of Set 4 | conceicao do araguaia
# Processing Record 6 of Set 4 | camacha
# Processing Record 7 of Set 4 | santa rosalia
# Processing Record 8 of Set 4 | omsukchan
# Processing Record 9 of Set 4 | chara
# Processing Record 10 of Set 4 | riyadh
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | cayenne
# Processing Record 13 of Set 4 | luganville
# Processing Record 14 of Set 4 | myanaung
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | praia
# Processing Record 17 of Set 4 | freeport
# Processing Record 18 of Set 4 | pagegiai
# Processing Record 19 of Set 4 | dobrinje
# Processing Record 20 of Set 4 | ponta do sol
# Processing Record 21 of Set 4 | cabinda
# Processing Record 22 of Set 4 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record 23 of Set 4 | hermanus
# Processing Record 24 of Set 4 | matelandia
# Processing Record 25 of Set 4 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record 26 of Set 4 | hambantota
# Processing Record 27 of Set 4 | myitkyina
# Processing Record 28 of Set 4 | zhoucheng
# Processing Record 29 of Set 4 | ribeira grande
# Processing Record 30 of Set 4 | gamba
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | warka
# Processing Record 33 of Set 4 | adwa
# Processing Record 34 of Set 4 | hamilton
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | leshukonskoye
# Processing Record 37 of Set 4 | mayor pablo lagerenza
# Processing Record 38 of Set 4 | ola
# Processing Record 39 of Set 4 | marawi
# Processing Record 40 of Set 4 | darab
# Processing Record 41 of Set 4 | peniche
# Processing Record 42 of Set 4 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record 43 of Set 4 | codrington
# Processing Record 44 of Set 4 | pandharpur
# Processing Record 45 of Set 4 | cedar rapids
# Processing Record 46 of Set 4 | nioro
# Processing Record 47 of Set 4 | tamale
# Processing Record 48 of Set 4 | varca
# Processing Record 49 of Set 4 | lebu
# Processing Record 50 of Set 4 | sinnamary
# Processing Record 1 of Set 5 | havre-saint-pierre
# Processing Record 2 of Set 5 | naron
# Processing Record 3 of Set 5 | mogochin
# mogochin not found. Skipping...
# Processing Record 4 of Set 5 | ferkessedougou
# Processing Record 5 of Set 5 | beloha
# Processing Record 6 of Set 5 | husavik
# Processing Record 7 of Set 5 | farrukhnagar
# Processing Record 8 of Set 5 | boende
# Processing Record 9 of Set 5 | tocopilla
# Processing Record 10 of Set 5 | la grande
# Processing Record 11 of Set 5 | purpe
# Processing Record 12 of Set 5 | hudson bay
# Processing Record 13 of Set 5 | camana
# Processing Record 14 of Set 5 | barrow
# Processing Record 15 of Set 5 | san angelo
# Processing Record 16 of Set 5 | fairbanks
# Processing Record 17 of Set 5 | missoula
# Processing Record 18 of Set 5 | monterey
# Processing Record 19 of Set 5 | sandnessjoen
# Processing Record 20 of Set 5 | taltal
# Processing Record 21 of Set 5 | garden city
# Processing Record 22 of Set 5 | itarema
# Processing Record 23 of Set 5 | tabialan
# tabialan not found. Skipping...
# Processing Record 24 of Set 5 | bathsheba
# Processing Record 25 of Set 5 | whitianga
# Processing Record 26 of Set 5 | pak phanang
# Processing Record 27 of Set 5 | hofn
# Processing Record 28 of Set 5 | clyde river
# Processing Record 29 of Set 5 | karratha
# Processing Record 30 of Set 5 | souillac
# Processing Record 31 of Set 5 | bunia
# Processing Record 32 of Set 5 | vila
# Processing Record 33 of Set 5 | bejuco
# Processing Record 34 of Set 5 | kailua
# Processing Record 35 of Set 5 | bari
# Processing Record 36 of Set 5 | katsuura
# Processing Record 37 of Set 5 | lompoc
# Processing Record 38 of Set 5 | bafoulabe
# Processing Record 39 of Set 5 | tucurui
# Processing Record 40 of Set 5 | mana
# Processing Record 41 of Set 5 | deputatskiy
# Processing Record 42 of Set 5 | ossora
# Processing Record 43 of Set 5 | praya
# Processing Record 44 of Set 5 | mount gambier
# Processing Record 45 of Set 5 | rio grande city
# Processing Record 46 of Set 5 | jiuquan
# Processing Record 47 of Set 5 | leningradskiy
# Processing Record 48 of Set 5 | la paz
# Processing Record 49 of Set 5 | bognor regis
# Processing Record 50 of Set 5 | lorengau
# Processing Record 1 of Set 6 | dingle
# Processing Record 2 of Set 6 | san quintin
# Processing Record 3 of Set 6 | sao filipe
# Processing Record 4 of Set 6 | chokurdakh
# Processing Record 5 of Set 6 | waingapu
# Processing Record 6 of Set 6 | mehriz
# Processing Record 7 of Set 6 | bima
# Processing Record 8 of Set 6 | acapulco
# Processing Record 9 of Set 6 | tautira
# Processing Record 10 of Set 6 | warqla
# warqla not found. Skipping...
# Processing Record 11 of Set 6 | mecca
# Processing Record 12 of Set 6 | artyk
# artyk not found. Skipping...
# Processing Record 13 of Set 6 | flin flon
# Processing Record 14 of Set 6 | namibe
# Processing Record 15 of Set 6 | kamenskoye
# kamenskoye not found. Skipping...
# Processing Record 16 of Set 6 | smoky lake
# Processing Record 17 of Set 6 | sao joao dos montes
# Processing Record 18 of Set 6 | avera
# Processing Record 19 of Set 6 | pisco
# Processing Record 20 of Set 6 | te anau
# Processing Record 21 of Set 6 | tiksi
# Processing Record 22 of Set 6 | hasaki
# Processing Record 23 of Set 6 | kaitangata
# Processing Record 24 of Set 6 | newark
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | saint george
# Processing Record 27 of Set 6 | suoyarvi
# Processing Record 28 of Set 6 | gafanha da encarnacao
# Processing Record 29 of Set 6 | taoudenni
# Processing Record 30 of Set 6 | kant
# Processing Record 31 of Set 6 | heyang
# Processing Record 32 of Set 6 | pasighat
# Processing Record 33 of Set 6 | constitucion
# Processing Record 34 of Set 6 | mattru
# Processing Record 35 of Set 6 | zeya
# Processing Record 36 of Set 6 | nexo
# Processing Record 37 of Set 6 | salalah
# Processing Record 38 of Set 6 | brae
# Processing Record 39 of Set 6 | ituango
# Processing Record 40 of Set 6 | mtwara
# Processing Record 41 of Set 6 | irbeyskoye
# Processing Record 42 of Set 6 | eidfjord
# Processing Record 43 of Set 6 | vardo
# Processing Record 44 of Set 6 | requena
# Processing Record 45 of Set 6 | los llanos de aridane
# Processing Record 46 of Set 6 | tianpeng
# Processing Record 47 of Set 6 | port lincoln
# Processing Record 48 of Set 6 | waw
# Processing Record 49 of Set 6 | linqiong
# Processing Record 50 of Set 6 | elko
# Processing Record 1 of Set 7 | sur
# Processing Record 2 of Set 7 | burgeo
# Processing Record 3 of Set 7 | birchis
# Processing Record 4 of Set 7 | pizhanka
# Processing Record 5 of Set 7 | kamaishi
# Processing Record 6 of Set 7 | plattsburgh
# Processing Record 7 of Set 7 | ler
# Processing Record 8 of Set 7 | pandan
# Processing Record 9 of Set 7 | nouakchott
# Processing Record 10 of Set 7 | sambava
# Processing Record 11 of Set 7 | barcelos
# Processing Record 12 of Set 7 | south lake tahoe
# Processing Record 13 of Set 7 | sterling
# Processing Record 14 of Set 7 | dali
# Processing Record 15 of Set 7 | kyshtovka
# Processing Record 16 of Set 7 | keti bandar
# Processing Record 17 of Set 7 | san patricio
# Processing Record 18 of Set 7 | kuznechnoye
# Processing Record 19 of Set 7 | san juan
# Processing Record 20 of Set 7 | bethel
# Processing Record 21 of Set 7 | san luis
# Processing Record 22 of Set 7 | las cruces
# Processing Record 23 of Set 7 | paradwip
# paradwip not found. Skipping...
# Processing Record 24 of Set 7 | hay river
# Processing Record 25 of Set 7 | lazaro cardenas
# Processing Record 26 of Set 7 | busdi
# Processing Record 27 of Set 7 | zavolzhsk
# Processing Record 28 of Set 7 | laramie
# Processing Record 29 of Set 7 | necochea
# Processing Record 30 of Set 7 | mutsu
# Processing Record 31 of Set 7 | japura
# Processing Record 32 of Set 7 | raurkela
# raurkela not found. Skipping...
# Processing Record 33 of Set 7 | airai
# Processing Record 34 of Set 7 | hirado
# Processing Record 35 of Set 7 | pacifica
# Processing Record 36 of Set 7 | fare
# Processing Record 37 of Set 7 | nenjiang
# Processing Record 38 of Set 7 | wufeng
# Processing Record 39 of Set 7 | paamiut
# Processing Record 40 of Set 7 | akyab
# Processing Record 41 of Set 7 | bara
# Processing Record 42 of Set 7 | tysons corner
# Processing Record 43 of Set 7 | shengjin
# Processing Record 44 of Set 7 | bayir
# Processing Record 45 of Set 7 | nguiu
# nguiu not found. Skipping...
# Processing Record 46 of Set 7 | rawson
# Processing Record 47 of Set 7 | shakawe
# Processing Record 48 of Set 7 | darnetal
# Processing Record 49 of Set 7 | tuktoyaktuk
# Processing Record 50 of Set 7 | fomboni
# Processing Record 1 of Set 8 | rosetta
# Processing Record 2 of Set 8 | phuthaditjhaba
# Processing Record 3 of Set 8 | pemangkat
# Processing Record 4 of Set 8 | mauguio
# Processing Record 5 of Set 8 | chapais
# Processing Record 6 of Set 8 | faanui
# Processing Record 7 of Set 8 | ulladulla
# Processing Record 8 of Set 8 | dong hoi
# Processing Record 9 of Set 8 | marshfield
# Processing Record 10 of Set 8 | powell river
# Processing Record 11 of Set 8 | hualmay
# Processing Record 12 of Set 8 | yatou
# Processing Record 13 of Set 8 | nantucket
# Processing Record 14 of Set 8 | darhan
# Processing Record 15 of Set 8 | shimanovsk
# Processing Record 16 of Set 8 | monitos
# Processing Record 17 of Set 8 | balykshi
# Processing Record 18 of Set 8 | kulhudhuffushi
# Processing Record 19 of Set 8 | victoria
# Processing Record 20 of Set 8 | buenos aires
# Processing Record 21 of Set 8 | kununurra
# Processing Record 22 of Set 8 | caravelas
# Processing Record 23 of Set 8 | rassvet
# Processing Record 24 of Set 8 | vulcan
# Processing Record 25 of Set 8 | touros
# Processing Record 26 of Set 8 | antalaha
# Processing Record 27 of Set 8 | sao geraldo do araguaia
# Processing Record 28 of Set 8 | talnakh
# Processing Record 29 of Set 8 | nouadhibou
# Processing Record 30 of Set 8 | chifeng
# Processing Record 31 of Set 8 | lagoa
# Processing Record 32 of Set 8 | mehamn
# Processing Record 33 of Set 8 | bargal
# bargal not found. Skipping...
# Processing Record 34 of Set 8 | fort nelson
# Processing Record 35 of Set 8 | mergui
# mergui not found. Skipping...
# Processing Record 36 of Set 8 | skagastrond
# skagastrond not found. Skipping...
# Processing Record 37 of Set 8 | shkotovo-26
# shkotovo-26 not found. Skipping...
# Processing Record 38 of Set 8 | kilindoni
# Processing Record 39 of Set 8 | terney
# Processing Record 40 of Set 8 | makakilo city
# Processing Record 41 of Set 8 | guerrero negro
# Processing Record 42 of Set 8 | talcahuano
# Processing Record 43 of Set 8 | shimsk
# Processing Record 44 of Set 8 | celestun
# Processing Record 45 of Set 8 | kayerkan
# Processing Record 46 of Set 8 | iskateley
# Processing Record 47 of Set 8 | ambilobe
# Processing Record 48 of Set 8 | high prairie
# Processing Record 49 of Set 8 | satitoa
# satitoa not found. Skipping...
# Processing Record 50 of Set 8 | dingtao
# Processing Record 1 of Set 9 | sjenica
# Processing Record 2 of Set 9 | gat
# Processing Record 3 of Set 9 | agbor
# Processing Record 4 of Set 9 | bloemfontein
# Processing Record 5 of Set 9 | kruisfontein
# Processing Record 6 of Set 9 | naze
# Processing Record 7 of Set 9 | kotdwara
# Processing Record 8 of Set 9 | herat
# Processing Record 9 of Set 9 | fortuna
# Processing Record 10 of Set 9 | altamira
# Processing Record 11 of Set 9 | svetlogorsk
# Processing Record 12 of Set 9 | georgetown
# Processing Record 13 of Set 9 | calama
# Processing Record 14 of Set 9 | bambous virieux
# Processing Record 15 of Set 9 | desna
# Processing Record 16 of Set 9 | pesochnoye
# Processing Record 17 of Set 9 | galveston
# Processing Record 18 of Set 9 | salinopolis
# Processing Record 19 of Set 9 | alyangula
# Processing Record 20 of Set 9 | alofi
# Processing Record 21 of Set 9 | weyburn
# Processing Record 22 of Set 9 | pangai
# Processing Record 23 of Set 9 | domoni
# Processing Record 24 of Set 9 | san lazaro
# Processing Record 25 of Set 9 | port hedland
# Processing Record 26 of Set 9 | kestel
# Processing Record 27 of Set 9 | bon air
# Processing Record 28 of Set 9 | paraibano
# Processing Record 29 of Set 9 | najran
# Processing Record 30 of Set 9 | mihailesti
# Processing Record 31 of Set 9 | verkhnyaya inta
# Processing Record 32 of Set 9 | lampang
# Processing Record 33 of Set 9 | blackfoot
# Processing Record 34 of Set 9 | lara
# Processing Record 35 of Set 9 | seymchan
# Processing Record 36 of Set 9 | jieshi
# Processing Record 37 of Set 9 | kabinda
# Processing Record 38 of Set 9 | iesolo
# Processing Record 39 of Set 9 | geraldton
# Processing Record 40 of Set 9 | manokwari
# Processing Record 41 of Set 9 | shahrud
# Processing Record 42 of Set 9 | kieta
# Processing Record 43 of Set 9 | glendive
# Processing Record 44 of Set 9 | ilulissat
# Processing Record 45 of Set 9 | okhotsk
# Processing Record 46 of Set 9 | sidlaghatta
# Processing Record 47 of Set 9 | erenhot
# Processing Record 48 of Set 9 | bramming
# Processing Record 49 of Set 9 | kahului
# Processing Record 50 of Set 9 | lolua
# lolua not found. Skipping...
# Processing Record 1 of Set 10 | sorvag
# sorvag not found. Skipping...
# Processing Record 2 of Set 10 | port-gentil
# Processing Record 3 of Set 10 | bereda
# Processing Record 4 of Set 10 | laela
# Processing Record 5 of Set 10 | marcona
# marcona not found. Skipping...
# Processing Record 6 of Set 10 | oussouye
# Processing Record 7 of Set 10 | sao joao da barra
# Processing Record 8 of Set 10 | chimbote
# Processing Record 9 of Set 10 | gigmoto
# Processing Record 10 of Set 10 | metro
# Processing Record 11 of Set 10 | ulaanbaatar
# Processing Record 12 of Set 10 | xinqing
# Processing Record 13 of Set 10 | gueret
# Processing Record 14 of Set 10 | kargasok
# Processing Record 15 of Set 10 | vao
# Processing Record 16 of Set 10 | grand gaube
# Processing Record 17 of Set 10 | port blair
# Processing Record 18 of Set 10 | goundam
# Processing Record 19 of Set 10 | sembakung
# Processing Record 20 of Set 10 | sarakhs
# Processing Record 21 of Set 10 | dinard
# Processing Record 22 of Set 10 | lucea
# Processing Record 23 of Set 10 | aleksandrovskiy zavod
# Processing Record 24 of Set 10 | vertientes
# Processing Record 25 of Set 10 | bakchar
# Processing Record 26 of Set 10 | sampit
# Processing Record 27 of Set 10 | ondarroa
# Processing Record 28 of Set 10 | wanaka
# Processing Record 29 of Set 10 | zhigansk
# Processing Record 30 of Set 10 | kyaukse
# Processing Record 31 of Set 10 | orchard homes
# Processing Record 32 of Set 10 | yulara
# Processing Record 33 of Set 10 | grong
# Processing Record 34 of Set 10 | luoyang
# Processing Record 35 of Set 10 | hokitika
# Processing Record 36 of Set 10 | maneadero
# Processing Record 37 of Set 10 | axim
# Processing Record 38 of Set 10 | idrinskoye
# Processing Record 39 of Set 10 | safranbolu
# Processing Record 40 of Set 10 | inirida
# Processing Record 41 of Set 10 | key west
# Processing Record 42 of Set 10 | broadstairs
# Processing Record 43 of Set 10 | yablonovo
# Processing Record 44 of Set 10 | san andres
# Processing Record 45 of Set 10 | babaeski
# Processing Record 46 of Set 10 | tual
# Processing Record 47 of Set 10 | carutapera
# Processing Record 48 of Set 10 | batticaloa
# Processing Record 49 of Set 10 | viedma
# Processing Record 50 of Set 10 | otjiwarongo
# Processing Record 1 of Set 11 | ligayan
# Processing Record 2 of Set 11 | komsomolskiy
# Processing Record 3 of Set 11 | san cristobal
# Processing Record 4 of Set 11 | kokoda
# Processing Record 5 of Set 11 | sao jose da coroa grande
# Processing Record 6 of Set 11 | biu
# Processing Record 7 of Set 11 | prince george
# Processing Record 8 of Set 11 | cherskiy
# Processing Record 9 of Set 11 | opuwo
# Processing Record 10 of Set 11 | beringovskiy
# Processing Record 11 of Set 11 | palabuhanratu
# palabuhanratu not found. Skipping...
# Processing Record 12 of Set 11 | lefka
# Processing Record 13 of Set 11 | mujiayingzi
# Processing Record 14 of Set 11 | skelleftea
# Processing Record 15 of Set 11 | mackenzie
# Processing Record 16 of Set 11 | bairiki
# Processing Record 17 of Set 11 | mont-de-marsan
# Processing Record 18 of Set 11 | matara
# Processing Record 19 of Set 11 | maryville
# Processing Record 20 of Set 11 | roberto payan
# roberto payan not found. Skipping...
# Processing Record 21 of Set 11 | serebryanyy bor
# Processing Record 22 of Set 11 | asau
# Processing Record 23 of Set 11 | saint-denis
# Processing Record 24 of Set 11 | foumbot
# Processing Record 25 of Set 11 | maniitsoq
# Processing Record 26 of Set 11 | maldonado
# Processing Record 27 of Set 11 | tolaga bay
# Processing Record 28 of Set 11 | dargaville
# Processing Record 29 of Set 11 | bubaque
# Processing Record 30 of Set 11 | bemidji
# Processing Record 31 of Set 11 | westport
# Processing Record 32 of Set 11 | anshan
# Processing Record 33 of Set 11 | libreville
# Processing Record 34 of Set 11 | calais
# Processing Record 35 of Set 11 | maniwaki
# Processing Record 36 of Set 11 | atocha
# Processing Record 37 of Set 11 | nelson bay
# Processing Record 38 of Set 11 | diamantino
# Processing Record 39 of Set 11 | pingliang
# Processing Record 40 of Set 11 | kromy
# Processing Record 41 of Set 11 | naqadeh
# Processing Record 42 of Set 11 | biltine
# Processing Record 43 of Set 11 | rungata
# rungata not found. Skipping...
# Processing Record 44 of Set 11 | maebaru
# Processing Record 45 of Set 11 | mnogovershinnyy
# Processing Record 46 of Set 11 | sobolevo
# Processing Record 47 of Set 11 | vilhena
# Processing Record 48 of Set 11 | rundu
# Processing Record 49 of Set 11 | lagunas
# Processing Record 50 of Set 11 | yoichi
# Processing Record 1 of Set 12 | rudnytsya
# rudnytsya not found. Skipping...
# Processing Record 2 of Set 12 | yumen
# Processing Record 3 of Set 12 | batagay-alyta
# Processing Record 4 of Set 12 | sayat
# Processing Record 5 of Set 12 | chore
# chore not found. Skipping...
# Processing Record 6 of Set 12 | west fargo
# Processing Record 7 of Set 12 | hami
# Processing Record 8 of Set 12 | meyungs
# meyungs not found. Skipping...
# Processing Record 9 of Set 12 | lake charles
# Processing Record 10 of Set 12 | pouembout
# Processing Record 11 of Set 12 | asekeyevo
# Processing Record 12 of Set 12 | college
# Processing Record 13 of Set 12 | barra da estiva
# Processing Record 14 of Set 12 | babushkin
# Processing Record 15 of Set 12 | ambon
# Processing Record 16 of Set 12 | vittoria
# Processing Record 17 of Set 12 | tromso
# Processing Record 18 of Set 12 | shelburne
# Processing Record 19 of Set 12 | palmas bellas
# Processing Record 20 of Set 12 | shingu
# Processing Record 21 of Set 12 | victor harbor
# Processing Record 22 of Set 12 | marinette
# Processing Record 23 of Set 12 | inuvik
# Processing Record 24 of Set 12 | kirakira
# Processing Record 25 of Set 12 | zhanatas
# zhanatas not found. Skipping...
# Processing Record 26 of Set 12 | stephenville
# Processing Record 27 of Set 12 | lahr
# Processing Record 28 of Set 12 | rabo de peixe
# Processing Record 29 of Set 12 | lasa
# Processing Record 30 of Set 12 | ust-uda
# Processing Record 31 of Set 12 | manicore
# Processing Record 32 of Set 12 | grafton
# Processing Record 33 of Set 12 | tessalit
# Processing Record 34 of Set 12 | tilichiki
# Processing Record 35 of Set 12 | jaciara
# Processing Record 36 of Set 12 | coahuayana
# Processing Record 37 of Set 12 | roanne
# Processing Record 38 of Set 12 | bhatapara
# Processing Record 39 of Set 12 | mrirt
# mrirt not found. Skipping...
# Processing Record 40 of Set 12 | saint-joseph
# Processing Record 41 of Set 12 | vostok
# Processing Record 42 of Set 12 | ponta delgada
# Processing Record 43 of Set 12 | skagen
# Processing Record 44 of Set 12 | hihifo
# hihifo not found. Skipping...
# Processing Record 45 of Set 12 | puerto colombia
# Processing Record 46 of Set 12 | baruun-urt
# Processing Record 47 of Set 12 | lakes entrance
# Processing Record 48 of Set 12 | passo fundo
# Processing Record 49 of Set 12 | dwarka
# Processing Record 50 of Set 12 | galgani
# galgani not found. Skipping...
# Processing Record 1 of Set 13 | pocone
# Processing Record 2 of Set 13 | port macquarie
# Processing Record 3 of Set 13 | qaqortoq
# Processing Record 4 of Set 13 | wroclaw
# Processing Record 5 of Set 13 | marica
# Processing Record 6 of Set 13 | melilla
# Processing Record 7 of Set 13 | quelimane
# Processing Record 8 of Set 13 | quesnel
# Processing Record 9 of Set 13 | saundatti yellamma
# saundatti yellamma not found. Skipping...
# Processing Record 10 of Set 13 | tabuk
# Processing Record 11 of Set 13 | ningxiang
# Processing Record 12 of Set 13 | phonhong
# Processing Record 13 of Set 13 | ca mau
# Processing Record 14 of Set 13 | lubyany
# Processing Record 15 of Set 13 | mogadishu
# Processing Record 16 of Set 13 | meridian
# Processing Record 17 of Set 13 | pangnirtung
# Processing Record 18 of Set 13 | moree
# Processing Record 19 of Set 13 | rincon
# Processing Record 20 of Set 13 | turukhansk
# Processing Record 21 of Set 13 | aklavik
# Processing Record 22 of Set 13 | nordlingen
# nordlingen not found. Skipping...
# Processing Record 23 of Set 13 | bulgan
# Processing Record 24 of Set 13 | seydisehir
# Processing Record 25 of Set 13 | makokou
# Processing Record 26 of Set 13 | antofagasta
# Processing Record 27 of Set 13 | teguldet
# Processing Record 28 of Set 13 | wahiawa
# Processing Record 29 of Set 13 | lamar
# Processing Record 30 of Set 13 | marv dasht
# marv dasht not found. Skipping...
# Processing Record 31 of Set 13 | bonavista
# Processing Record 32 of Set 13 | boa vista
# Processing Record 33 of Set 13 | villazon
# Processing Record 34 of Set 13 | damghan
# Processing Record 35 of Set 13 | fukue
# Processing Record 36 of Set 13 | dongsheng
# Processing Record 37 of Set 13 | dolbeau
# dolbeau not found. Skipping...
# Processing Record 38 of Set 13 | la ronge
# Processing Record 39 of Set 13 | vestmanna
# Processing Record 40 of Set 13 | loa janan
# Processing Record 41 of Set 13 | bambanglipuro
# Processing Record 42 of Set 13 | mahadday weyne
# mahadday weyne not found. Skipping...
# Processing Record 43 of Set 13 | sarangani
# Processing Record 44 of Set 13 | zarand
# Processing Record 45 of Set 13 | zhezkazgan
# Processing Record 46 of Set 13 | tuggurt
# tuggurt not found. Skipping...
# Processing Record 47 of Set 13 | port augusta
# Processing Record 48 of Set 13 | auki
# Processing Record 49 of Set 13 | gravdal
# Processing Record 50 of Set 13 | hinatuan
# Processing Record 1 of Set 14 | nokaneng
# Processing Record 2 of Set 14 | kirgiz-miyaki
# Processing Record 3 of Set 14 | rio gallegos
# Processing Record 4 of Set 14 | alekseyevsk
# Processing Record 5 of Set 14 | san policarpo
# Processing Record 6 of Set 14 | half moon bay
# Processing Record 7 of Set 14 | dahra
# Processing Record 8 of Set 14 | quirinopolis
# Processing Record 9 of Set 14 | gresham park
# Processing Record 10 of Set 14 | komsomolskoye
# Processing Record 11 of Set 14 | gao
# Processing Record 12 of Set 14 | kalmunai
# Processing Record 13 of Set 14 | nara
# Processing Record 14 of Set 14 | nemuro
# Processing Record 15 of Set 14 | samusu
# samusu not found. Skipping...
# Processing Record 16 of Set 14 | muzhi
# Processing Record 17 of Set 14 | filadelfia
# Processing Record 18 of Set 14 | tarquinia
# Processing Record 19 of Set 14 | sesheke
# Processing Record 20 of Set 14 | tuy hoa
# Processing Record 21 of Set 14 | walla walla
# Processing Record 22 of Set 14 | ayagoz
# Processing Record 23 of Set 14 | wageningen
# Processing Record 24 of Set 14 | ozgon
# ozgon not found. Skipping...
# Processing Record 25 of Set 14 | shizunai
# Processing Record 26 of Set 14 | havelock
# Processing Record 27 of Set 14 | manitouwadge
# Processing Record 28 of Set 14 | zyryanka
# Processing Record 29 of Set 14 | huilong
# Processing Record 30 of Set 14 | koungou
# Processing Record 31 of Set 14 | wulanhaote
# wulanhaote not found. Skipping...
# Processing Record 32 of Set 14 | veinticinco de mayo
# Processing Record 33 of Set 14 | sungai padi
# Processing Record 34 of Set 14 | baherden
# Processing Record 35 of Set 14 | abu zabad
# Processing Record 36 of Set 14 | karatau
# Processing Record 37 of Set 14 | samarai
# Processing Record 38 of Set 14 | colares
# Processing Record 39 of Set 14 | kabalo
# Processing Record 40 of Set 14 | cururupu
# Processing Record 41 of Set 14 | anito
# Processing Record 42 of Set 14 | wawa
# Processing Record 43 of Set 14 | kadyy
# Processing Record 44 of Set 14 | orange
# Processing Record 45 of Set 14 | houma
# Processing Record 46 of Set 14 | santa isabel
# Processing Record 47 of Set 14 | noumea
# Processing Record 48 of Set 14 | nhulunbuy
# Processing Record 49 of Set 14 | reitz
# Processing Record 50 of Set 14 | ziarat
# Processing Record 1 of Set 15 | black river
# Processing Record 2 of Set 15 | quzhou
# Processing Record 3 of Set 15 | jumla
# Processing Record 4 of Set 15 | inhambane
# Processing Record 5 of Set 15 | olavarria
# Processing Record 6 of Set 15 | mednogorsk
# Processing Record 7 of Set 15 | cumaribo
# cumaribo not found. Skipping...
# Processing Record 8 of Set 15 | siay
# Processing Record 9 of Set 15 | talkha
# Processing Record 10 of Set 15 | borovskoy
# Processing Record 11 of Set 15 | betsiamites
# Processing Record 12 of Set 15 | tartagal
# Processing Record 13 of Set 15 | sayyan
# Processing Record 14 of Set 15 | kudat
# Processing Record 15 of Set 15 | nchelenge
# Processing Record 16 of Set 15 | pontianak
# Processing Record 17 of Set 15 | ahuimanu
# Processing Record 18 of Set 15 | sawang daen din
# Processing Record 19 of Set 15 | bajo baudo
# bajo baudo not found. Skipping...
# Processing Record 20 of Set 15 | bucerias
# Processing Record 21 of Set 15 | pochutla
# Processing Record 22 of Set 15 | jinan
# Processing Record 23 of Set 15 | sinkat
# sinkat not found. Skipping...
# Processing Record 24 of Set 15 | comodoro rivadavia
# Processing Record 25 of Set 15 | sringeri
# Processing Record 26 of Set 15 | coihaique
# Processing Record 27 of Set 15 | hobyo
# Processing Record 28 of Set 15 | harur
# Processing Record 29 of Set 15 | bad oldesloe
# Processing Record 30 of Set 15 | cap malheureux
# Processing Record 31 of Set 15 | xining
# Processing Record 32 of Set 15 | rafai
# Processing Record 33 of Set 15 | suntar
# Processing Record 34 of Set 15 | temaraia
# temaraia not found. Skipping...
# Processing Record 35 of Set 15 | ocampo
# Processing Record 36 of Set 15 | kurumkan
# Processing Record 37 of Set 15 | lourdes
# Processing Record 38 of Set 15 | kihei
# Processing Record 39 of Set 15 | burica
# burica not found. Skipping...
# Processing Record 40 of Set 15 | benjamin hill
# Processing Record 41 of Set 15 | kropotkin
# Processing Record 42 of Set 15 | isabela
# Processing Record 43 of Set 15 | odweyne
# Processing Record 44 of Set 15 | chumikan
# Processing Record 45 of Set 15 | fonte boa
# Processing Record 46 of Set 15 | zhangye
# Processing Record 47 of Set 15 | morant bay
# Processing Record 48 of Set 15 | buchanan
# Processing Record 49 of Set 15 | kuytun
# Processing Record 50 of Set 15 | barbar
# barbar not found. Skipping...
# Processing Record 1 of Set 16 | oistins
# Processing Record 2 of Set 16 | ust-kamchatsk
# ust-kamchatsk not found. Skipping...
# Processing Record 3 of Set 16 | margherita
# Processing Record 4 of Set 16 | nuuk
# Processing Record 5 of Set 16 | kamenka
# Processing Record 6 of Set 16 | birnin kebbi
# Processing Record 7 of Set 16 | altay
# Processing Record 8 of Set 16 | alice town
# Processing Record 9 of Set 16 | satun
# Processing Record 10 of Set 16 | kuryk
# Processing Record 11 of Set 16 | mahajanga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.to_csv('WeatherPy_Database.csv')

# %%
city_data_df.count()
# Out:
# City                   700
# Lat                    700
# Lng                    700
# Max Temp               700
# Humidity               700
# Cloudiness             700
# Wind Speed             700
# Country                700
# Date                   700
# Current Description    700
# dtype: int64
